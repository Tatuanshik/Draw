# %%
import pandas as pd

# %%
import matplotlib.pyplot as plt

# %%
from testovoe import Draw

# %%
url = 'https://ai-process-sandy.s3.eu-west-1.amazonaws.com/purge/deviation.json'

# %%
dif = Draw(url)
dif.create_folder()
paths = dif.draw_plots()
dataframe = dif.create_dataframe()
dataframe.head()

for path in paths:
    img = plt.imread(path)
    plt.figure(figsize=(7, 7))
    plt.imshow(img)
    plt.axis('off')
    plt.show()
